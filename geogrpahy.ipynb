# %%
import os
import requests
from dotenv import load_dotenv

load_dotenv()

MAPBOX_API_KEY = os.getenv("MAPBOX_API_KEY")

# %%
class Geocoder:

    def __init__(self):
        self.api_key = MAPBOX_API_KEY

    def geocode(self, place_name):

        url = f"https://api.mapbox.com/geocoding/v5/mapbox.places/{place_name}.json"

        params = {
            "access_token": self.api_key,
            "limit": 1
        }

        response = requests.get(url, params=params)
        data = response.json()

        if data["features"]:

            longitude, latitude = data["features"][0]["center"]

            return {
                "latitude": latitude,
                "longitude": longitude
            }

        return None

# %%
if __name__ == "__main__":

    geocoder = Geocoder()

    location = geocoder.geocode("Amber Fort, Jaipur")

    print(location)
# Out:
# {'latitude': 26.988088, 'longitude': 75.855085}
